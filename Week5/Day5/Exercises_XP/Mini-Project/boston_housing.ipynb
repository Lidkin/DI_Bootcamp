# %% [markdown]
# # Part 1

# %% [markdown]
# ## 1.

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns

# %%
data_bh = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv')
data_bh
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# ## 2.

# %%
data_bh.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
data_bh.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
data_bh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
data_bh.hist(bins=50, figsize=(50,50))
plt.tight_layout()
plt.show()

# %%
sns.pairplot(data_bh, x_vars=data_bh.columns[:-1], y_vars=['medv'], hue="medv")
# Out:
# C:\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## 3.

# %%
data_bh.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
data_bh_norm = (data_bh-data_bh.min())/(data_bh.max()- data_bh.min())
data_bh_norm
# Out:
#          crim    zn     indus  chas       nox        rm       age       dis  \
# 0    0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607  0.269203
# 1    0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698  0.348962
# 2    0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382  0.348962
# 3    0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813  0.448545
# 4    0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321  0.448545
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 501  0.000633  0.00  0.420455   0.0  0.386831  0.580954  0.681771  0.122671
# 502  0.000438  0.00  0.420455   0.0  0.386831  0.490324  0.760041  0.105293
# 503  0.000612  0.00  0.420455   0.0  0.386831  0.654340  0.907312  0.094381
# 504  0.001161  0.00  0.420455   0.0  0.386831  0.619467  0.889804  0.114514
# 505  0.000462  0.00  0.420455   0.0  0.386831  0.473079  0.802266  0.125072
#
# ...

# %% [markdown]
# ## 4.

# %%
data_bh_norm['age_category'] = pd.cut(data_bh_norm['age'],bins=[0.0,0.30,0.60,0.90],labels=['new','old','very_old'])
data_bh_norm.head()
# Out:
#        crim    zn     indus  chas       nox        rm       age       dis  \
# 0  0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607  0.269203
# 1  0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698  0.348962
# 2  0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382  0.348962
# 3  0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813  0.448545
# 4  0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321  0.448545
#
#         rad       tax   ptratio         b     lstat      medv age_category
# 0  0.000000  0.208015  0.287234  1.000000  0.089680  0.422222     very_old
# 1  0.043478  0.104962  0.553191  1.000000  0.204470  0.368889     very_old
# 2  0.043478  0.104962  0.553191  0.989737  0.063466  0.660000          old
# 3  0.086957  0.066794  0.648936  0.994276  0.033389  0.631111          old
# 4  0.086957  0.066794  0.648936  1.000000  0.099338  0.693333          old

# %% [markdown]
# ## 5.

# %%
correlations = []
for column in data_bh[:-1]:
    correlations.append(data_bh[column].corr(data_bh['medv']))
correlations
# Out:
# [-0.3883046085868113,
#  0.36044534245054277,
#  -0.4837251600283727,
#  0.17526017719029854,
#  -0.42732077237328264,
#  0.6953599470715395,
#  -0.3769545650045963,
#  0.24992873408590388,
#  -0.38162623063977763,
#  -0.468535933567767,
#  -0.5077866855375617,
#  0.33346081965706653,
#  -0.7376627261740147,
#  1.0]

# %%
data_bh_cor = data_bh.corrwith(data_bh['medv'])

# %%
data_bh_cor
# Out:
# crim      -0.388305
# zn         0.360445
# indus     -0.483725
# chas       0.175260
# nox       -0.427321
# rm         0.695360
# age       -0.376955
# dis        0.249929
# rad       -0.381626
# tax       -0.468536
# ptratio   -0.507787
# b          0.333461
# lstat     -0.737663
# medv       1.000000
# dtype: float64

# %%
ax = sns.heatmap(data_bh.corr()[['medv']], annot=True)
ax.set(xlabel="", ylabel="")
ax.xaxis.tick_top()

# %% [markdown]
# # Part II

# %%
new_properties = data_bh[data_bh['age'] <= 35]
old_properties = data_bh[(data_bh['age'] > 35) & (data_bh['age'] <= 70)]
very_old_properties = data_bh[data_bh['age'] > 70]

# %%
new_median_price = new_properties['medv'].median()
old_median_price = old_properties['medv'].median()
very_old_median_price = very_old_properties['medv'].median()

plt.figure(figsize=(10, 6))

plt.bar('New', new_median_price, color='blue', label='New Properties')
plt.bar('Old', old_median_price, color='green', label='Old Properties')
plt.bar('Very Old', very_old_median_price, color='red', label='Very Old Properties')

plt.xlabel('Age Group')
plt.ylabel('Median Price')
plt.title('Median Price vs. Property Age Group')
plt.legend()
plt.show()

# %% [markdown]
# # Part III

# %%
bins = [0, 1, 5, 10, 20, max(data_bh['crim'])]
labels = ['0-1', '1-5', '5-10', '10-20', '20+']
data_bh['crim_bin'] = pd.cut(data_bh['crim'], bins=bins, labels=labels)

# %%
avg_MEDV_per_CRIM_BIN = data_bh.groupby('crim_bin')['medv'].mean()

# %%
plt.figure(figsize=(10, 6))

plt.plot(avg_MEDV_per_CRIM_BIN, marker='o')
plt.xlabel('Binned Crime Rate')
plt.ylabel('Average Property Price (MEDV)')
plt.title('Neighborhood Crime Rate Impact on Property Prices')
plt.xticks(range(len(labels)), labels)  # Set x-axis ticks to match the crime rate bins
plt.grid(True)
plt.show()
